# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48,
                          2000: 45,
                          2001: 50})
series_test2
# Out:
# 1999    48
# 2000    45
# 2001    50
# dtype: int64

# %%
frame_test = pd.DataFrame({1999: [10, 20, 30],
                           2000: [40, 50, 60],
                           2001: [70, 80, 90]})

frame_test
# Out:
#    1999  2000  2001
# 0    10    40    70
# 1    20    50    80
# 2    30    60    90

# %%
frame_test2 = pd.DataFrame([[10, 20, 30],
                           [40, 50, 60],
                           [70, 80, 90]], columns = [1999, 2000, 2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    10    20    30
# 1    40    50    60
# 2    70    80    90

# %%
el_universal = pd.read_csv('Data_Sets/eluniversal_2018_11_08_articles.csv')

el_universal
# Out:
#                                                   body  \
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# ..                                                 ...
# 130  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 131  La actriz Ximena Córdoba participa en la obra ...
# 132  \nVolkswagen presentó hoy una nueva pick-up qu...
# 133  Antonio Gali Fayad, gobernador de Puebla, reci...
# 134  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                  title  \
# 0    UAEM: Garantizado semestre agosto-diciembre 2018
# 1                                                  NaN
# 2    Ernesto Cordero seguirá fuera del partido, ins...
# 3                            Premio Nacional de Dopaje
# 4     Manchester United derrota a la Juventus en Turín
# ..                                                 ...
# 130  Con taller de pintura y grabado, obra de inter...
# 131          Ximena Córdoba participa en Las Recogidas
# 132       Volkswagen presenta Tarok, su nueva pick-up
# 133  OCDE reconoce a gobierno de Puebla por su polí...
# 134  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                    url
# 0    http://www.union-morelos.mx/articulo/2018/11/0...
# 1    http://de10.com.mx/top-10/2018/11/06/10-actore...
# 2    http://www.eluniversal.com.mx/nacion/politica/...
# 3    https://www.eluniversal.com.mx/columna/gerardo...
# 4    http://www.eluniversal.com.mx/universal-deport...
# ..                                                 ...
# 130  http://oaxaca.eluniversal.com.mx/especiales/23...
# 131  http://www.unionedomex.mx/articulo/2018/11/07/...
# 132  http://www.eluniversal.com.mx/autopistas/volks...
# 133  http://www.unionpuebla.mx/articulo/2018/11/07/...
# 134  http://www.eluniversal.com.mx/metropoli/se-van...
#
# [135 rows x 3 columns]

# %%
### Métodos de visualización de datos ###

# dictionary_like

el_universal[['body', 'title']]
# Out:
#                                                   body  \
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# ..                                                 ...
# 130  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 131  La actriz Ximena Córdoba participa en la obra ...
# 132  \nVolkswagen presentó hoy una nueva pick-up qu...
# 133  Antonio Gali Fayad, gobernador de Puebla, reci...
# 134  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                  title
# 0    UAEM: Garantizado semestre agosto-diciembre 2018
# 1                                                  NaN
# 2    Ernesto Cordero seguirá fuera del partido, ins...
# 3                            Premio Nacional de Dopaje
# 4     Manchester United derrota a la Juventus en Turín
# ..                                                 ...
# 130  Con taller de pintura y grabado, obra de inter...
# 131          Ximena Córdoba participa en Las Recogidas
# 132       Volkswagen presenta Tarok, su nueva pick-up
# 133  OCDE reconoce a gobierno de Puebla por su polí...
# 134  Se van 500 mdp por un tubo en forma de “K inve...
#
# [135 rows x 2 columns]

# %%
# numpy_like

el_universal.iloc[:10]
# Out:
#                                                 body  \
# 0  Gustavo Urquiza Beltrán, rector de la Universi...
# 1   0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2  \nEl Partido Acción Nacional (PAN), señaló que...
# 3  \nSe dieron a conocer los ganadores del Premio...
# 4  \nLa remontada del Manchester United en el cam...
# 5  \nEl encontronazo entre las bancadas que confo...
# 6  \nTexto: Dafne N. García LópezDiseño web: Migu...
# 7  \nTexto: Nayeli ReyesFoto actual: Susana Colin...
# 8  Lourdes León, hija de Madonna, optó por un atr...
# 9  Geny Falla es la cocinera yucateca que más hum...
#
#                                                title  \
# 0  UAEM: Garantizado semestre agosto-diciembre 2018
# 1                                                NaN
# 2  Ernesto Cordero seguirá fuera del partido, ins...
# 3                          Premio Nacional de Dopaje
# 4   Manchester United derrota a la Juventus en Turín
# 5  Diputados "reavivan" discusión por visita de N...
# 6  El periodista que heredó su fortuna para la cr...
# 7         La tradición de “comer” a nuestros muertos
# 8                                                NaN
# 9       Geny, cocinera yucateca en MasterChef México
#
#                                                  url
# 0  http://www.union-morelos.mx/articulo/2018/11/0...
# 1  http://de10.com.mx/top-10/2018/11/06/10-actore...
# 2  http://www.eluniversal.com.mx/nacion/politica/...
# 3  https://www.eluniversal.com.mx/columna/gerardo...
# 4  http://www.eluniversal.com.mx/universal-deport...
# 5  http://www.eluniversal.com.mx/nacion/politica/...
# 6  https://www.eluniversal.com.mx/mochilazo-en-el...
# 7  https://www.eluniversal.com.mx/mochilazo-en-el...
# 8  https://www.viveusa.mx/showbiz/hija-de-madonna...
# 9  http://www.unionyucatan.mx/articulo/2018/11/06...

# %%
el_universal.iloc[9][['body', 'title', 'url']]
# Out:
# body     Geny Falla es la cocinera yucateca que más hum...
# title         Geny, cocinera yucateca en MasterChef México
# url      http://www.unionyucatan.mx/articulo/2018/11/06...
# Name: 9, dtype: object

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# Name: body, dtype: object

# %%
el_universal.loc[:5, 'body']
# Out:
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# 5    \nEl encontronazo entre las bancadas que confo...
# Name: body, dtype: object

# %%
### Proceso de ENRIQUECIMIENTO de datos ###

# Creación de ID

el_universal['newspaper_uid'] = 'el_universal'

el_universal
# Out:
#                                                   body  \
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# ..                                                 ...
# 130  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 131  La actriz Ximena Córdoba participa en la obra ...
# 132  \nVolkswagen presentó hoy una nueva pick-up qu...
# 133  Antonio Gali Fayad, gobernador de Puebla, reci...
# 134  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                  title  \
# 0    UAEM: Garantizado semestre agosto-diciembre 2018
# 1                                                  NaN
# 2    Ernesto Cordero seguirá fuera del partido, ins...
# 3                            Premio Nacional de Dopaje
# 4     Manchester United derrota a la Juventus en Turín
# ..                                                 ...
# 130  Con taller de pintura y grabado, obra de inter...
# 131          Ximena Córdoba participa en Las Recogidas
# 132       Volkswagen presenta Tarok, su nueva pick-up
# 133  OCDE reconoce a gobierno de Puebla por su polí...
# 134  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                    url newspaper_uid
# 0    http://www.union-morelos.mx/articulo/2018/11/0...  el_universal
# 1    http://de10.com.mx/top-10/2018/11/06/10-actore...  el_universal
# 2    http://www.eluniversal.com.mx/nacion/politica/...  el_universal
# 3    https://www.eluniversal.com.mx/columna/gerardo...  el_universal
# 4    http://www.eluniversal.com.mx/universal-deport...  el_universal
# ..                                                 ...           ...
# 130  http://oaxaca.eluniversal.com.mx/especiales/23...  el_universal
# 131  http://www.unionedomex.mx/articulo/2018/11/07/...  el_universal
# 132  http://www.eluniversal.com.mx/autopistas/volks...  el_universal
# 133  http://www.unionpuebla.mx/articulo/2018/11/07/...  el_universal
# 134  http://www.eluniversal.com.mx/metropoli/se-van...  el_universal
#
# [135 rows x 4 columns]

# %%
# Obtener HOST de URL

from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# ..                                                 ...
# 130  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 131  La actriz Ximena Córdoba participa en la obra ...
# 132  \nVolkswagen presentó hoy una nueva pick-up qu...
# 133  Antonio Gali Fayad, gobernador de Puebla, reci...
# 134  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                  title  \
# 0    UAEM: Garantizado semestre agosto-diciembre 2018
# 1                                                  NaN
# 2    Ernesto Cordero seguirá fuera del partido, ins...
# 3                            Premio Nacional de Dopaje
# 4     Manchester United derrota a la Juventus en Turín
# ..                                                 ...
# 130  Con taller de pintura y grabado, obra de inter...
# 131          Ximena Córdoba participa en Las Recogidas
# 132       Volkswagen presenta Tarok, su nueva pick-up
# 133  OCDE reconoce a gobierno de Puebla por su polí...
# 134  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                    url newspaper_uid  \
# 0    http://www.union-morelos.mx/articulo/2018/11/0...  el_universal
# 1    http://de10.com.mx/top-10/2018/11/06/10-actore...  el_universal
# 2    http://www.eluniversal.com.mx/nacion/politica/...  el_universal
# 3    https://www.eluniversal.com.mx/columna/gerardo...  el_universal
# 4    http://www.eluniversal.com.mx/universal-deport...  el_universal
# ..                                                 ...           ...
# 130  http://oaxaca.eluniversal.com.mx/especiales/23...  el_universal
# 131  http://www.unionedomex.mx/articulo/2018/11/07/...  el_universal
# 132  http://www.eluniversal.com.mx/autopistas/volks...  el_universal
# 133  http://www.unionpuebla.mx/articulo/2018/11/07/...  el_universal
# 134  http://www.eluniversal.com.mx/metropoli/se-van...  el_universal
#
#                           host
# 0         www.union-morelos.mx
# 1                  de10.com.mx
# 2       www.eluniversal.com.mx
# 3       www.eluniversal.com.mx
# 4       www.eluniversal.com.mx
# ..                         ...
# 130  oaxaca.eluniversal.com.mx
# 131         www.unionedomex.mx
# 132     www.eluniversal.com.mx
# 133         www.unionpuebla.mx
# 134     www.eluniversal.com.mx
#
# [135 rows x 5 columns]

# %%
# Valores y frecuencias dentro de DataFrame

el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         75
# de10.com.mx                     9
# www.viveusa.mx                  9
# www.elbotiquin.mx               6
# oaxaca.eluniversal.com.mx       5
# www.eluniversalqueretaro.mx     5
# www.elgrafico.mx                5
# sanluis.eluniversal.com.mx      5
# www.unionpuebla.mx              4
# www.unionguanajuato.mx          2
# www.union-morelos.mx            2
# www.unionjalisco.mx             2
# www.unionedomex.mx              2
# www.unionyucatan.mx             2
# www.clubeluniversal.mx          1
# www.unioncdmx.mx                1
# Name: host, dtype: int64

# %%
#  Verificación de datos faltantes

missing_title_mask = el_universal['title'].isna()

missing_title_mask
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# Name: title, Length: 135, dtype: bool

# %%
# Detección de titulos faltantes en la URL

missing_titles = (el_universal[missing_title_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                 )

missing_titles
# Out:
#                                         missing_titles
# 1    10 actores menores de 30 anos que son famosos ...
# 8    hija de madonna deslumbra con braless y transp...
# 10   video carambola mortal en la autopista mexico ...
# 15   la verdadera relacion entre freddie mercury y ...
# 23   salma hayek cambia de look se transforma en pe...
# 30   video kim kardashian impacta con sexy rutina d...
# 31   encuentran cuerpo de mujer violada en una azot...
# 40   hasta en la sopa 10 productos que se comercial...
# 43             que es el sindrome de piernas inquietas
# 47   quien es lorde 10 datos para conocer la pequen...
# 53   paul prenter el hombre que todos odiamos en bo...
# 57   los estados de eu donde es mas probable que se...
# 59   ellos hicieron historia en las elecciones inte...
# 61        la enfermedad que llena la boca de dientes 0
# 63   la verdadera relacion entre freddie mercury y ...
# 66   cual fue tu favorito 20 anos del vive latino t...
# 73                como es la cirugia de cambio de sexo
# 77   bella hadid altera nueva york con braless y bl...
# 79   ex novio de kim kardashian revela detalles sex...
# 83   destinos de eu y canada donde encontraras cast...
# 86        7 senales de que la menopausia llego tu vida
# 93                  la guerra de los logos por la cdmx
# 94             los juguetes mas populares para navidad
# 98   10 cosas que no deberias googlear por tu salud...
# 99   diosa de instagram burla la censura y presume ...
# 100  emily ratajkowski presume la tendencia sin pan...
# 102                                      suscripciones
# 108    10 dudas sobre la vida y trabajo de marie curie
# 116  ejecuta de un plomazo al amante de su esposa e...
# 123                   como se usa una copita menstrual
# 126        tener sexo casual puede provocarte ansiedad

# %%
# Asignación de datos faltantes a columna de TITLE

el_universal.loc[missing_title_mask, 'title'] = missing_titles.loc[:,'missing_titles']

el_universal
# Out:
#                                                   body  \
# 0    Gustavo Urquiza Beltrán, rector de la Universi...
# 1     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 2    \nEl Partido Acción Nacional (PAN), señaló que...
# 3    \nSe dieron a conocer los ganadores del Premio...
# 4    \nLa remontada del Manchester United en el cam...
# ..                                                 ...
# 130  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 131  La actriz Ximena Córdoba participa en la obra ...
# 132  \nVolkswagen presentó hoy una nueva pick-up qu...
# 133  Antonio Gali Fayad, gobernador de Puebla, reci...
# 134  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                  title  \
# 0    UAEM: Garantizado semestre agosto-diciembre 2018
# 1    10 actores menores de 30 anos que son famosos ...
# 2    Ernesto Cordero seguirá fuera del partido, ins...
# 3                            Premio Nacional de Dopaje
# 4     Manchester United derrota a la Juventus en Turín
# ..                                                 ...
# 130  Con taller de pintura y grabado, obra de inter...
# 131          Ximena Córdoba participa en Las Recogidas
# 132       Volkswagen presenta Tarok, su nueva pick-up
# 133  OCDE reconoce a gobierno de Puebla por su polí...
# 134  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                    url newspaper_uid  \
# 0    http://www.union-morelos.mx/articulo/2018/11/0...  el_universal
# 1    http://de10.com.mx/top-10/2018/11/06/10-actore...  el_universal
# 2    http://www.eluniversal.com.mx/nacion/politica/...  el_universal
# 3    https://www.eluniversal.com.mx/columna/gerardo...  el_universal
# 4    http://www.eluniversal.com.mx/universal-deport...  el_universal
# ..                                                 ...           ...
# 130  http://oaxaca.eluniversal.com.mx/especiales/23...  el_universal
# 131  http://www.unionedomex.mx/articulo/2018/11/07/...  el_universal
# 132  http://www.eluniversal.com.mx/autopistas/volks...  el_universal
# 133  http://www.unionpuebla.mx/articulo/2018/11/07/...  el_universal
# 134  http://www.eluniversal.com.mx/metropoli/se-van...  el_universal
#
#                           host
# 0         www.union-morelos.mx
# 1                  de10.com.mx
# 2       www.eluniversal.com.mx
# 3       www.eluniversal.com.mx
# 4       www.eluniversal.com.mx
# ..                         ...
# 130  oaxaca.eluniversal.com.mx
# 131         www.unionedomex.mx
# 132     www.eluniversal.com.mx
# 133         www.unionpuebla.mx
# 134     www.eluniversal.com.mx
#
# [135 rows x 5 columns]

# %%
# Codificación de indice (UID) para la filas

import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis = 1)
            .apply(lambda hash_object: hash_object.hexdigest())
       )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  Gustavo Urquiza Beltrán, rector de la Universi...
# ce3aad5e3741a90b620e4e015ab89a17   0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 146f26d2ab7251643ac36528fb5a99c6  \nEl Partido Acción Nacional (PAN), señaló que...
# 34f124d0a2b4a69db343112050c8de36  \nSe dieron a conocer los ganadores del Premio...
# cd022eb8686f8a0faa4e5815e44de23b  \nLa remontada del Manchester United en el cam...
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 1af3affa838ebfb68028a5f6187e7824  La actriz Ximena Córdoba participa en la obra ...
# 6999ba4766d4468368962410c51b3e8a  \nVolkswagen presentó hoy una nueva pick-up qu...
# f614db294ee13309f2f55039ee02883d  Antonio Gali Fayad, gobernador de Puebla, reci...
# 6463b065f6968a96b463fbb0a2901ba4  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                                               title  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  UAEM: Garantizado semestre agosto-diciembre 2018
# ce3aad5e3741a90b620e4e015ab89a17  10 actores menores de 30 anos que son famosos ...
# 146f26d2ab7251643ac36528fb5a99c6  Ernesto Cordero seguirá fuera del partido, ins...
# 34f124d0a2b4a69db343112050c8de36                          Premio Nacional de Dopaje
# cd022eb8686f8a0faa4e5815e44de23b   Manchester United derrota a la Juventus en Turín
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  Con taller de pintura y grabado, obra de inter...
# 1af3affa838ebfb68028a5f6187e7824          Ximena Córdoba participa en Las Recogidas
# 6999ba4766d4468368962410c51b3e8a       Volkswagen presenta Tarok, su nueva pick-up
# f614db294ee13309f2f55039ee02883d  OCDE reconoce a gobierno de Puebla por su polí...
# 6463b065f6968a96b463fbb0a2901ba4  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                                                 url  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  http://www.union-morelos.mx/articulo/2018/11/0...
# ce3aad5e3741a90b620e4e015ab89a17  http://de10.com.mx/top-10/2018/11/06/10-actore...
# 146f26d2ab7251643ac36528fb5a99c6  http://www.eluniversal.com.mx/nacion/politica/...
# 34f124d0a2b4a69db343112050c8de36  https://www.eluniversal.com.mx/columna/gerardo...
# cd022eb8686f8a0faa4e5815e44de23b  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  http://oaxaca.eluniversal.com.mx/especiales/23...
# 1af3affa838ebfb68028a5f6187e7824  http://www.unionedomex.mx/articulo/2018/11/07/...
# 6999ba4766d4468368962410c51b3e8a  http://www.eluniversal.com.mx/autopistas/volks...
# f614db294ee13309f2f55039ee02883d  http://www.unionpuebla.mx/articulo/2018/11/07/...
# 6463b065f6968a96b463fbb0a2901ba4  http://www.eluniversal.com.mx/metropoli/se-van...
#
#                                  newspaper_uid                       host
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  el_universal       www.union-morelos.mx
# ce3aad5e3741a90b620e4e015ab89a17  el_universal                de10.com.mx
# 146f26d2ab7251643ac36528fb5a99c6  el_universal     www.eluniversal.com.mx
# 34f124d0a2b4a69db343112050c8de36  el_universal     www.eluniversal.com.mx
# cd022eb8686f8a0faa4e5815e44de23b  el_universal     www.eluniversal.com.mx
# ...                                        ...                        ...
# 1e1d33aaac7e66a82a1798422a20cb6c  el_universal  oaxaca.eluniversal.com.mx
# 1af3affa838ebfb68028a5f6187e7824  el_universal         www.unionedomex.mx
# 6999ba4766d4468368962410c51b3e8a  el_universal     www.eluniversal.com.mx
# f614db294ee13309f2f55039ee02883d  el_universal         www.unionpuebla.mx
# 6463b065f6968a96b463fbb0a2901ba4  el_universal     www.eluniversal.com.mx
#
# [135 rows x 5 columns]

# %%
# Borrado de saltos de línea (\n)

stripped_body = ( el_universal
                     .apply(lambda row: row['body'], axis = 1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                     .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee    Gustavo Urquiza Beltrán, rector de la Universi...
# ce3aad5e3741a90b620e4e015ab89a17     0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 146f26d2ab7251643ac36528fb5a99c6    El Partido Acción Nacional (PAN), señaló que t...
# 34f124d0a2b4a69db343112050c8de36    Se dieron a conocer los ganadores del Premio N...
# cd022eb8686f8a0faa4e5815e44de23b    La remontada del Manchester United en el campo...
#                                                           ...
# 1e1d33aaac7e66a82a1798422a20cb6c    ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 1af3affa838ebfb68028a5f6187e7824    La actriz Ximena Córdoba participa en la obra ...
# 6999ba4766d4468368962410c51b3e8a    Volkswagen presentó hoy una nueva pick-up que ...
# f614db294ee13309f2f55039ee02883d    Antonio Gali Fayad, gobernador de Puebla, reci...
# 6463b065f6968a96b463fbb0a2901ba4    Read in English[email protected]Villa de Allen...
# Length: 135, dtype: object

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Buscado de palabras específicas dentro del texto

import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis = 1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
#                 .apply(lambda word_list: list(filter(lambda word: word is not stop_words, word_list)))
#                 .apply(lambda valid_word_list: len(valid_word_list))
           )

el_universal['n_tokens'] = tokenize_column(el_universal, 'body')

el_universal
# Out:
#                                                                                body  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  Gustavo Urquiza Beltrán, rector de la Universi...
# ce3aad5e3741a90b620e4e015ab89a17   0 % PULSO SOCIAL0 Si de algo puede estar orgu...
# 146f26d2ab7251643ac36528fb5a99c6  \nEl Partido Acción Nacional (PAN), señaló que...
# 34f124d0a2b4a69db343112050c8de36  \nSe dieron a conocer los ganadores del Premio...
# cd022eb8686f8a0faa4e5815e44de23b  \nLa remontada del Manchester United en el cam...
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  ¡El balonero!, ¡el destache! ¡la borrega!, ¡el...
# 1af3affa838ebfb68028a5f6187e7824  La actriz Ximena Córdoba participa en la obra ...
# 6999ba4766d4468368962410c51b3e8a  \nVolkswagen presentó hoy una nueva pick-up qu...
# f614db294ee13309f2f55039ee02883d  Antonio Gali Fayad, gobernador de Puebla, reci...
# 6463b065f6968a96b463fbb0a2901ba4  \nRead in English\n[email protected]\n\nVilla ...
#
#                                                                               title  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  UAEM: Garantizado semestre agosto-diciembre 2018
# ce3aad5e3741a90b620e4e015ab89a17  10 actores menores de 30 anos que son famosos ...
# 146f26d2ab7251643ac36528fb5a99c6  Ernesto Cordero seguirá fuera del partido, ins...
# 34f124d0a2b4a69db343112050c8de36                          Premio Nacional de Dopaje
# cd022eb8686f8a0faa4e5815e44de23b   Manchester United derrota a la Juventus en Turín
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  Con taller de pintura y grabado, obra de inter...
# 1af3affa838ebfb68028a5f6187e7824          Ximena Córdoba participa en Las Recogidas
# 6999ba4766d4468368962410c51b3e8a       Volkswagen presenta Tarok, su nueva pick-up
# f614db294ee13309f2f55039ee02883d  OCDE reconoce a gobierno de Puebla por su polí...
# 6463b065f6968a96b463fbb0a2901ba4  Se van 500 mdp por un tubo en forma de “K inve...
#
#                                                                                 url  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  http://www.union-morelos.mx/articulo/2018/11/0...
# ce3aad5e3741a90b620e4e015ab89a17  http://de10.com.mx/top-10/2018/11/06/10-actore...
# 146f26d2ab7251643ac36528fb5a99c6  http://www.eluniversal.com.mx/nacion/politica/...
# 34f124d0a2b4a69db343112050c8de36  https://www.eluniversal.com.mx/columna/gerardo...
# cd022eb8686f8a0faa4e5815e44de23b  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 1e1d33aaac7e66a82a1798422a20cb6c  http://oaxaca.eluniversal.com.mx/especiales/23...
# 1af3affa838ebfb68028a5f6187e7824  http://www.unionedomex.mx/articulo/2018/11/07/...
# 6999ba4766d4468368962410c51b3e8a  http://www.eluniversal.com.mx/autopistas/volks...
# f614db294ee13309f2f55039ee02883d  http://www.unionpuebla.mx/articulo/2018/11/07/...
# 6463b065f6968a96b463fbb0a2901ba4  http://www.eluniversal.com.mx/metropoli/se-van...
#
#                                  newspaper_uid                       host  \
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee  el_universal       www.union-morelos.mx
# ce3aad5e3741a90b620e4e015ab89a17  el_universal                de10.com.mx
# 146f26d2ab7251643ac36528fb5a99c6  el_universal     www.eluniversal.com.mx
# 34f124d0a2b4a69db343112050c8de36  el_universal     www.eluniversal.com.mx
# cd022eb8686f8a0faa4e5815e44de23b  el_universal     www.eluniversal.com.mx
# ...                                        ...                        ...
# 1e1d33aaac7e66a82a1798422a20cb6c  el_universal  oaxaca.eluniversal.com.mx
# 1af3affa838ebfb68028a5f6187e7824  el_universal         www.unionedomex.mx
# 6999ba4766d4468368962410c51b3e8a  el_universal     www.eluniversal.com.mx
# f614db294ee13309f2f55039ee02883d  el_universal         www.unionpuebla.mx
# 6463b065f6968a96b463fbb0a2901ba4  el_universal     www.eluniversal.com.mx
#
#                                   n_tokens
# uid
# a3b5b01ab7f4eb30d08a6a34a4d4a1ee       285
# ce3aad5e3741a90b620e4e015ab89a17       215
# 146f26d2ab7251643ac36528fb5a99c6       272
# 34f124d0a2b4a69db343112050c8de36       537
# cd022eb8686f8a0faa4e5815e44de23b       171
# ...                                    ...
# 1e1d33aaac7e66a82a1798422a20cb6c      1115
# 1af3affa838ebfb68028a5f6187e7824       111
# 6999ba4766d4468368962410c51b3e8a       210
# f614db294ee13309f2f55039ee02883d       239
# 6463b065f6968a96b463fbb0a2901ba4       576
#
# [135 rows x 6 columns]

# %%
el_pais = pd.read_csv('Data_Sets/elpais_2018_11_08_articles.csv')

el_pais
# Out:
#                                                  body  \
# 0   \n\n\n\nMÁS INFORMACIÓN\n\n\n\n\n\n\n\n\n\n\n\...
# 1   \nExiste una frase instalada en la cultura pol...
# 2   \nHace tiempo que se sabe que a Gerard Piqué l...
# 3   \nLa prensa y la opinión pública mexicana resp...
# 4   \n\n\n\nMÁS INFORMACIÓN\n\n\n\n\n\n\n\n\n\n\n\...
# ..                                                ...
# 72  \n“En 1939, Canadá rechazó a 907 refugiados ju...
# 73  \nCuatro meses después de que se destapase la ...
# 74  \nEl más reciente informe del Programa Interna...
# 75  \nEl gran hermano te vigila. Tiene control sob...
# 76  \nMacron no quiere partidos, sino superarlos, ...
#
#                                                 title  \
# 0   Esta enfermedad es ya la mayor amenaza nutrici...
# 1                         “Son las mujeres, estúpido”
# 2                     El Barça sigue de pie sin Messi
# 3                ¿Qué se necesita para una dictadura?
# 4               México busca la cura a la infelicidad
# ..                                                ...
# 72  Trudeau pide perdón por los refugiados judíos ...
# 73  Los fiscales que investigan la corrupción en l...
# 74  Canadá: un sistema de educación descentralizad...
# 75                                  Algo está podrido
# 76  Rivera ultima la alianza con Macron para las e...
#
#                                                   url
# 0   https://elpais.com/elpais/2018/11/06/planeta_f...
# 1   https://elpais.com/internacional/2018/11/07/es...
# 2   https://elpais.com/deportes/2018/11/07/actuali...
# 3   https://elpais.com/internacional/2018/11/08/me...
# 4   https://elpais.com/elpais/2018/11/06/planeta_f...
# ..                                                ...
# 72  https://elpais.com/internacional/2018/11/08/ac...
# 73  https://elpais.com/internacional/2018/11/07/ac...
# 74  https://elpais.com/sociedad/2018/11/06/actuali...
# 75  https://elpais.com/internacional/2018/11/07/co...
# 76  https://elpais.com/politica/2018/11/07/actuali...
#
# [77 rows x 3 columns]

# %%
el_pais.isna()
# Out:
#      body  title    url
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# ..    ...    ...    ...
# 72  False  False  False
# 73  False  False  False
# 74  False  False  False
# 75  False  False  False
# 76  False  False  False
#
# [77 rows x 3 columns]
